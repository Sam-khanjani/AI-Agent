# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
from dotenv import load_dotenv
# Load variables from .env into the environment
load_dotenv()

retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing advancements are set to revolutionize AI by significantly boosting its capabilities. This includes accelerating machine learning, improving optimization processes, and enhancing natural language processing. Quantum computers can tackle complex problems currently beyond classical AI and offer a more efficient and sustainable approach to AI development. Furthermore, AI is also expected to play a role in advancing quantum computing itself, creating a synergistic relationship between the two fields.

# %%
# Sequential order is improtant! So ...
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")


# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")


# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")


#Here we call SequentionalAgent to make sure order is satisfied correctly 
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ outline_agent created.
# ✅ writer_agent created.
# ✅ editor_agent created.
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Outline:
#
# **Headline:** Supercharge Your Code: The Multi-Agent Advantage for Software Developers
#
# **Introduction Hook:** Ever feel like your software projects are single-handedly fighting a dragon? What if you could unleash an army of specialized helpers to tackle complexity, boost efficiency, and deliver more robust solutions? Enter the world of Multi-Agent Systems (MAS) – a game-changer for modern software development.
#
# **Main Section 1: Tackling Complexity with Distributed Intelligence**
#
# *   **Decomposition Done Right:** MAS allows you to break down large, intricate problems into smaller, manageable sub-problems, each handled by an independent agent. This makes understanding and developing complex systems far more approachable.
# *   **Resilience and Robustness:** If one agent encounters an issue or fails, the system can often continue operating, re-allocating tasks or finding alternative solutions. This inherent fault tolerance is a huge win for reliability.
# *   **Parallel Processing Power:** Agents can operate concurrently, significantly speeding up computation and allowing for more complex simulations or analyses within realistic timeframes.
#
# **Main Section 2: Enhancing Collaboration and Coordination**
#
# *   **Specialized Skillsets:** Design agents with specific expertise – one for data validation, another for UI rendering, a third for database interaction. This allows for optimal task delegation and leverages the strengths of each agent.
# *   **Dynamic Task Allocation:** MAS can adapt to changing conditions by re-assigning tasks dynamically based on agent availability, load, and current project needs, leading to efficient resource utilization.
# *   **Inter-Agent Communication:** Develop sophisticated communication protocols between agents, enabling them to share information, negotiate solutions, and work together towards common goals, mimicking human team collaboration.
#
# **Main Section 3: Driving Innovation and Agility**
#
# *   **Rapid Prototyping and Iteration:** Quickly spin up and test new agent behaviors or functionalities without disrupting the entire system, accelerating the development and experimentation cycle.
# *   **Adaptive Learning and Evolution:** Design agents that can learn from their experiences and adapt their strategies over time, leading to systems that improve their performance and efficiency organically.
# *   **Open-Ended Problem Solving:** MAS is ideal for tackling ill-defined or emergent problems where predefined solutions are difficult to establish, offering a flexible framework for exploration and discovery.
#
# **Concluding Thought:** Embracing Multi-Agent Systems isn't just about adding more code; it's about fundamentally rethinking how we build software. By leveraging distributed intelligence, enhanced collaboration, and adaptive capabilities, developers can unlock new levels of efficiency, robustness, and innovation, transforming the way we create the digital world.
# WriterAgent > ## Supercharge Your Code: The Multi-Agent Advantage for Software Developers
#
# Ever feel like your software projects are single-handedly fighting a dragon? What if you could unleash an army of specialized helpers to tackle complexity, boost efficiency, and deliver more robust solutions? Enter the world of Multi-Agent Systems (MAS) – a game-changer for modern software development.
#
# MAS fundamentally shifts how we approach intricate problems. Instead of a monolithic structure, MAS allows you to decompose large challenges into smaller, manageable sub-problems, each handled by an independent agent. This distributed intelligence makes complex systems far more approachable. Plus, the inherent fault tolerance means if one agent stumbles, the system can often continue operating, re-allocating tasks and ensuring reliability. Imagine the parallel processing power as agents work concurrently, significantly speeding up computation.
#
# Collaboration is another superpower of MAS. Design agents with specialized skillsets – one for data validation, another for UI rendering, a third for database interaction. This allows for optimal task delegation. MAS can dynamically re-assign tasks based on agent availability and project needs, leading to efficient resource utilization. Sophisticated communication protocols enable these agents to share information and negotiate solutions, mimicking effective human teamwork.
#
# Finally, MAS drives innovation and agility. Quickly prototype and test new agent behaviors without disrupting the entire system, accelerating your development cycle. Agents can even learn from their experiences, adapting their strategies over time for organic improvement. This makes MAS ideal for tackling ill-defined problems, offering a flexible framework for exploration and discovery.
#
# Embracing Multi-Agent Systems isn't just about adding code; it's about rethinking software creation. By leveraging distributed intelligence, enhanced collaboration, and adaptive capabilities, developers can unlock new levels of efficiency, robustness, and innovation, transforming how we build the digital world.
# EditorAgent > ## Supercharge Your Code: The Multi-Agent Advantage for Software Developers
#
# Ever feel like your software projects are single-handedly fighting a dragon? What if you could unleash an army of specialized helpers to tackle complexity, boost efficiency, and deliver more robust solutions? Enter the world of Multi-Agent Systems (MAS) – a true game-changer for modern software development.
#
# MAS fundamentally shifts how we approach intricate problems. Instead of relying on a monolithic structure, MAS empowers you to decompose large challenges into smaller, manageable sub-problems. Each of these sub-problems is then handled by an independent agent. This approach, leveraging distributed intelligence, makes even the most complex systems far more approachable. Furthermore, MAS offers inherent fault tolerance; if one agent encounters an issue, the system can often continue operating seamlessly by re-allocating tasks, ensuring enhanced reliability. Imagine the power of parallel processing as multiple agents work concurrently, significantly speeding up computation and reducing development time.
#
# Collaboration is another superpower of MAS. You can design agents with specialized skillsets – perhaps one dedicated to data validation, another to UI rendering, and a third to database interaction. This allows for optimal task delegation, ensuring each part of your project is handled by the most capable "expert." MAS can also dynamically re-assign tasks based on agent availability and evolving project needs, leading to incredibly efficient resource utilization. Sophisticated communication protocols enable these agents to share information and negotiate solutions collaboratively, effectively mimicking effective human teamwork within your codebase.
#
# Finally, MAS is a powerful driver of innovation and agility. You can quickly prototype and test new agent behaviors or functionalities without disrupting the entire system, thereby accelerating your development cycle. Agents can even learn from their experiences, adapting their strategies over time for organic improvement. This makes MAS an ideal framework for tackling ill-defined problems or exploring emergent possibilities, offering a flexible environment for discovery and evolution.
#
# Embracing Multi-Agent Systems isn't just about adding more code; it's about fundamentally rethinking software creation. By harnessing distributed intelligence, fostering enhanced collaboration, and enabling adaptive capabilities, developers can unlock new levels of efficiency, robustness, and innovation, ultimately transforming how we build the digital world.

# %%
# Concurrent Execution when tasks are independent, speed matters, and you can execute concurrently.

# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")


# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")


# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")



# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ tech_researcher created.
# ✅ health_researcher created.
# ✅ finance_researcher created.
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > Here's a daily executive briefing across Tech, Health, and Finance:
#
# **Tech:** Artificial Intelligence (AI) continues its rapid integration across industries. Major tech firms are navigating the complexities of Industrial IoT, with some divesting non-core assets. The DEA is leveraging AI for enhanced enforcement, including drug origin determination and visual analysis. Meanwhile, cybersecurity remains a critical concern, as highlighted by a major cyberattack impacting a retail giant's profits.
#
# **Health:** The HLTH 2025 conference highlighted AI's growing role in healthcare, with a focus on clinical applications and addressing the challenges of implementation and change management. There's an increasing emphasis on women's health within cardiology and healthcare overall, noting historical male-centric design in medicine. Discussions also touch on the impact of site-of-care shifts and value-based care strategies.
#
# **Finance:** Financial institutions are closely monitoring AI, particularly ChatGPT, with a surge in interest for risk and compliance purposes. The global economy shows resilience above recessionary levels, though inflation and cost of living remain concerns in some regions. Key regulatory discussions involve digital assets, open banking, and capital requirements for large banks. Banks are also focusing on enhancing leadership teams and non-financial risk management.
# TechResearcher > **AI/ML Trends Shaping 2025**
#
# **Key Developments:**
#
# 1.  **Generative AI Expansion:** Moving beyond chatbots, generative AI is powering real business workflows in content creation, coding, and even complex multimedia like video and music. Companies are seeking demonstrated ROI from these applications.
# 2.  **Agentic AI:** AI systems are gaining autonomy, capable of completing entire tasks with minimal human input, automating workflows across various departments like finance and support.
# 3.  **Domain-Specific Models & Smaller Models (SLMs):** Highly specialized AI models are outperforming general ones, offering tailored solutions for specific industries and use cases. Smaller models also reduce costs and energy consumption.
#
# **Main Companies Involved:**
#
# *   **Cloud Providers:** AWS, Google Cloud, Microsoft Azure are leading with comprehensive ML platforms like SageMaker, Vertex AI, and Azure Machine Learning, offering scalability and integration.
# *   **AI Research & Model Builders:** OpenAI, Anthropic, and Google (with Gemini) are at the forefront of developing advanced AI models.
# *   **Hardware & Infrastructure:** NVIDIA remains crucial with its GPUs powering large-scale model training.
# *   **Specialized Platforms:** Databricks, Dataiku, H2O.ai, and DataRobot offer platforms for enterprise ML, AutoML, and collaboration.
#
# **Potential Impact:**
#
# These trends are driving significant efficiency gains across industries by automating tasks, enhancing decision-making, and personalizing customer experiences. The focus is shifting towards practical applications with measurable business impact and ROI. Ethical considerations and responsible AI development are also becoming increasingly important.
# HealthResearcher > ## Health Breakthroughs:
#
# **1. Gene Therapy for Inherited Diseases:** Advances in CRISPR and other gene-editing technologies are enabling treatments for conditions like sickle cell anemia and inherited hearing loss. Practical applications include restoring vision and correcting genetic defects. Timeline: Already in trials and early approvals, with wider adoption expected within 3-5 years.
#
# **2. CAR T-Cell Therapy for Brain Cancer:** Re-engineering a patient's immune cells (CAR T-cells) shows promise in treating aggressive brain cancers like glioblastoma. This therapy has already shown success in blood cancers. Timeline: Early clinical trials are ongoing, with potential for broader application in 5-7 years.
#
# **3. Non-Opioid Pain Relievers:** Development of non-opioid pain management drugs is advancing, with late-stage clinical trials showing effectiveness in reducing post-surgical pain with minimal side effects. Timeline: Potential market availability within 2-4 years.
#
# ## Technology Breakthroughs:
#
# **1. Agentic AI:** Autonomous AI agents capable of independent task execution are reshaping industries from self-driving cars to process automation. Timeline: Significant integration into various sectors is expected within the next 3-5 years.
#
# **2. Spatial Computing:** Merging physical and digital worlds via AR/VR, IoT, and AI is creating immersive experiences. Applications range from AR-guided surgery to virtual retail try-ons. Timeline: Market growth projections suggest widespread adoption within 5-10 years.
#
# **3. Post-Quantum Cryptography (PQC):** As quantum computing advances, PQC is crucial for securing data against future quantum decryption threats. Timeline: Development and implementation are ongoing, with initial widespread adoption anticipated in 7-10 years.
#
# ## Finance Breakthroughs:
#
# **1. Digital Green Bonds:** Innovations in digital bond issuance, including tokenized central bank money for settlement, are streamlining transactions and reducing costs. Timeline: Increasingly being adopted, with broader market integration expected in 2-4 years.
#
# **2. AI in Risk Decisioning:** Advanced AI and machine learning are revolutionizing risk assessment and user experience in financial services, enabling real-time decisions. Timeline: Already being implemented, with further sophistication and integration in 1-3 years.
#
# **3. Tokenization of Assets:** The creation of digital tokens representing real-world assets is expanding to areas like digital bonds and potentially other financial instruments, increasing liquidity and accessibility. Timeline: Early stages of adoption, with significant growth anticipated in 5-7 years.
# AggregatorAgent > ## Executive Summary: AI-Driven Transformation Across Industries
#
# Artificial Intelligence (AI) is the unifying force driving significant advancements across technology, health, and finance, with a clear shift towards practical applications and demonstrable ROI.
#
# In **Technology**, generative AI is moving beyond chatbots to power business workflows in content creation, coding, and multimedia, while **agentic AI** systems are gaining autonomy to automate tasks. The rise of domain-specific and smaller models offers tailored, cost-effective solutions. Cloud providers and AI research firms are leading these developments, with NVIDIA remaining critical for hardware infrastructure.
#
# **Health** is experiencing breakthroughs with gene therapy for inherited diseases and CAR T-cell therapy for brain cancer, alongside the development of non-opioid pain relievers, all showing promise for wider adoption in the coming years. AI is also playing an increasingly vital role in healthcare, from clinical applications to change management, with a growing focus on women's health.
#
# **Finance** is leveraging AI, particularly advanced models like ChatGPT, for enhanced risk decisioning and compliance. Innovations in digital green bonds and the tokenization of assets are streamlining financial transactions. While the global economy shows resilience, inflation remains a concern, and regulatory discussions around digital assets and capital requirements are ongoing.
#
# **Key Takeaways:**
#
# *   **AI is pervasive:** Its integration is accelerating across all sectors, from automating complex tasks to personalizing experiences.
# *   **Focus on ROI:** Companies are demanding tangible business impact and measurable results from AI investments.
# *   **Specialization is key:** Domain-specific AI models are becoming increasingly important for tailored solutions.
# *   **Ethical considerations:** Responsible AI development is paramount as these technologies become more sophisticated and autonomous.
# *   **Convergence:** Advances in areas like spatial computing and PQC, alongside evolving financial regulations, indicate a future of interconnected innovation.

# %%
# Loop Agent for when a task needs to be improved through cycles of feedback and revision

# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")



# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")



# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ initial_writer_agent created.
# ✅ critic_agent created.
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")



# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ refiner_agent created.
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias traced the salt-worn grooves of his workbench, the rhythmic crash of waves a familiar lullaby. For twenty years, the lighthouse had been his world, a solitary sentinel against the unforgiving sea. Tonight, however, was different. While clearing out a forgotten sea chest, his lantern light caught on something unusual: a rolled parchment, brittle with age.
#
# Unfurling it, Elias gasped. It wasn't paper, but some strange, leathery material. And it pulsed with a faint, ethereal glow. Strange symbols, unlike any he’d ever seen, swirled across its surface, shifting and reforming like bioluminescent plankton. A single, shimmering line, a path of light, extended from a crudely drawn island to a point marked with a pulsating star. A map, but to where? And who had left it? The lighthouse suddenly felt less like a prison and more like the beginning of an adventure.
# CriticAgent > The plot has a strong hook, introducing a mystery and the potential for adventure. However, it feels a bit rushed. The pacing could be improved by adding more description of Elias's emotional reaction to the discovery and perhaps a moment of hesitation or contemplation before his perspective shifts to viewing the lighthouse as the *beginning* of an adventure.
#
# Here are 2-3 actionable suggestions for improvement:
#
# 1.  **Deepen Elias's Internal Reaction:** Instead of just stating Elias gasped, show his internal reaction more fully. Describe his trembling hands, the sudden surge of adrenaline, or a moment of disbelief as he touches the strange material. This will make his shift from viewing the lighthouse as a "prison" to an "adventure" feel more earned and impactful.
#
# 2.  **Expand on the Map's Uniqueness:** While the description of the map is intriguing, elaborating on the "strange symbols" and their movement could create a stronger sense of wonder and otherworldliness. Are the symbols vaguely familiar in shape, or utterly alien? Does the shifting nature suggest sentience or a dynamic, active source? Adding a few more evocative details here would enhance the mystery.
#
# 3.  **Hint at the Map's Origin (Optional, but impactful):** Consider adding a subtle clue or a question Elias might pose to himself about *who* might have left such a map. Was it a previous keeper? A shipwrecked sailor? A more mythical being? Even a brief, speculative thought can add depth and intrigue to the narrative without giving too much away.
# RefinerAgent > Elias traced the salt-worn grooves of his workbench, the rhythmic crash of waves a familiar, almost mournful, lullaby. For twenty years, the lighthouse had been his entire world—a solitary sentinel perched against the unforgiving, indifferent sea. Tonight, however, the familiar solitude felt different, heavier. While clearing out a forgotten sea chest, a relic from a long-ago storm, his lantern light snagged on something unusual: a rolled parchment, brittle with age, tucked into a hidden compartment.
#
# His fingers, usually steady from years of routine, trembled as he reached for it. The material was unlike any paper he knew; it felt strangely supple, like aged leather or cured fish skin, and it pulsed with a faint, ethereal glow that seemed to emanate from within. As he carefully unfurled it, a wave of disbelief washed over him, prickling his skin. Strange symbols, unlike any script or carving he’d ever encountered—some coiled like ancient serpents, others sharp and geometric like fragmented stars—swirled across its surface. They didn’t merely sit there; they *moved*, shifting and reforming with a fluid, bioluminescent grace, like a school of phantom plankton captured in a luminous dance. A single, shimmering line of pure light traced a path from a crudely drawn island, its peaks sharp and defiant, to a distant point marked with a single, pulsating star.
#
# A map. But to where? His breath hitched. Who could have possibly left such an artifact in this isolated tower? He ran a fingertip over the glowing symbols, half-expecting them to burn, but they were cool to the touch, humming with a silent energy. Could this have been left by Old Man Hemlock, the keeper before him, whose tales of the sea were as wild as the storms he weathered? Or perhaps a desperate castaway, a soul lost to the very waves Elias guarded against? The pulsing star on the map seemed to beckon, a silent challenge whispered across the years. The lighthouse, for so long his comfortable cage, suddenly felt less like a prison and more like the precipice of an unimaginable adventure.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
